# %% [markdown]
# ## Create a string s containing your full name. Print the string.

# %%
name = 'Mudassir Khan'
print(name)
# Out:
# Mudassir Khan

# %% [markdown]
# ## Create a string s with a sentence of your choice and print its length.

# %%
sentance = 'I am Passinated for AI & Data Science'
print(len(sentance))
# Out:
# 37

# %% [markdown]
# ## Assign a string to a variable and check its data type using Python

# %%
st = 'Data Science'
print(type(st))
# Out:
# <class 'str'>

# %% [markdown]
# ## Create a variable word with the value "Python" and print the first character.

# %%
st = 'Python'
print(st[0])
# Out:
# P

# %% [markdown]
# ## Create a variable course with the value "Python" and print the character at index 3.

# %%
course = 'Python'
print(course[3])
# Out:
# h

# %% [markdown]
# ## Create a variable framework with the value "TensorFlow" and print the character at negative index -4.

# %%
framework = "TensorFlow"
framework[-4]
# Out:
# 'F'

# %% [markdown]
# ## Create a variable fruit with the value "Apple". Convert the string to uppercase and print it.

# %%
fruit = "Apple"
print(fruit.upper())
# Out:
# APPLE

# %% [markdown]
# ## Create a variable city with the value "Karachi". Convert the string to lowercase and print it.

# %%
city = 'KarAchi'
print(city.lower())
# Out:
# karachi

# %% [markdown]
# ## Create a variable framework with the value "Django". Check if the string starts with "D" and print True or False.

# %%
framework = "Django"
if framework[0] == 'D':
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# ## Create a variable subject with the value "Mathematics". Check if all characters are alphabetic and print True or False.

# %%
subject = "Methametics"
if subject.isalpha:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# ## Ask the user to enter their email in any format.
# ## and then Convert it into lowercase.

# %%
email = input('Enter their email in any format :)')
email = email.lower()
print(email)
# Out:
# Enter their email in any format :) mkHan01287832@gmail.com
# mkhan01287832@gmail.com

# %% [markdown]
# # check if a number is even or odd where number is taken as input

# %%
num = int(input("Enter a Number :)"))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a Number :) 456
# Even

# %% [markdown]
# # User se number lo:
#
# # agar number > 0 → "Positive"
# # warna → "Negative"

# %%
num = int(input("Enter a Number :)"))
if num > 0:
    print("+tive")
else:
    print("-tive")
# Out:
# Enter a Number :) 456465
# +tive

# %% [markdown]
# # User se password lo:
#
# # agar "python123" hai → "Access Granted"
# # warna → "Access Denied"

# %%
password = input("Enter your password :)")
if password.lower() == "python123":
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter your password :) python123
# Access Granted

# %% [markdown]
# # User se temperature lo:
#
# # agar > 30 → "Hot"
# # warna → "Normal"

# %%
temperature = int(input("Enter a Number :)"))
if num > 30:
    print("Hot")
else:
    print("Normal")
# Out:
# Enter a Number :) 45
# Hot

# %% [markdown]
# # User se naam lo:
# # agar naam "Ali" hai → "Welcome Ali"
# # warna → "Welcome User"

# %%
name = input("Enter your name ->")
if name.lower() == "ali":
    print("welcome ali".title())
else:
    print('welcome user'.title())
# Out:
# Enter your name -> ali
# Welcome Ali

# %% [markdown]
# # User se marks lo aur grade do:
#
# # 90+ → A
# # 80+ → B
# # 70+ → C
# # 60+ → D
# # warna → Fail

# %%
num = int(input("enter your marks".capitalize()))
if num >= 90 and num <= 100:
    print('Grade A')
elif num >= 80 and num <= 90:
    print('Grade B')
elif num >= 70 and num <= 80:
    print('Grade C')
elif num >= 60 and num <= 70:
    print('Grade D')
else:
    print('Fail')
# Out:
# Enter your marks 80
# Grade B

# %% [markdown]
# # User se day number (1–7) lo:
#
# # 1 → Monday
# # 2 → Tuesday
# ## ...
# # 7 → Sunday

# %%
day = int(input("enter day number".capitalize()))
if day == 1:
    print("monday".capitalize())
elif day == 2:
    print("tuesday".capitalize())
elif day == 3:
    print("wednesday".capitalize())
elif day == 4:
    print("thursday".capitalize())
elif day == 5:
    print("friday".capitalize())
elif day == 6:
    print("saturday".capitalize())
elif day == 7:
    print("sunday".capitalize())
else:
    print("you gave wrong input".title())
# Out:
# Enter day number 5
# Friday

# %% [markdown]
# # User se month number lo:
#
# # 12,1,2 → Winter
# # 3,4,5 → Spring
# # 6,7,8 → Summer
# # warna → Autumn

# %%
month = int(input("enter month number".capitalize()))
if month == 1 or month == 2 or month == 12:
    print("Winter")
elif month == 3 or month == 4 or month == 5:
    print("Spring")
elif month == 6 or month == 7 or month == 8:
    print("Summer")
else:
    print("Autumn")
# Out:
# Enter month number 6
# Summer

# %% [markdown]
# # User se 2 numbers lo:
#
# # pehla > dusra → "First is greater"
# # pehla < dusra → "Second is greater"
# # warna → "Both equal"

# %%
n1 = int(input("enter first number".title()))
n2 = int(input("enter second number".title()))

if n1 > n2:
    print("First is greater")
elif n1 < n2:
    print("Second is greater")
else:
    print('Both equal')
# Out:
# Enter First Number 34
# Enter Second Number 675
# Second is greater

# %% [markdown]
# # Simple calculator:
# # User se operator lo (+, -, *, /):
#
# # → addition
# # → subtraction
# # → multiplication
# # / → division
# # warna → "Invalid operator"

# %%
operator = input("Enter an Operator")
operator = operator.strip().lower()

if operator == '+':
    print("Addition")
elif operator == '-':
    print("Subtraction")
elif operator == '*' or operator == 'x':
    print("Multiplication")
elif operator == '/':
    print("Division")
else:
    print("Invalid Operator")
# Out:
# Enter an Operator X
# Multiplication
